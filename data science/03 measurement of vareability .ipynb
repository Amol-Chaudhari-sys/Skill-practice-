# %%
import numpy as np
import pandas as pd 
import seaborn as sns
# import matplotlab.pyplot as plt

# %%
dataset= pd.read_csv("Practice1.csv")

# %%
dataset.head (9)
# Out:
#    Project Name              Task Name Assigned to Start Date  Days Required  \
# 0     Marketing        Market Research       Alice   1/1/2024             13
# 1     Marketing       Content Creation         Bob  1/14/2024             14
# 2     Marketing  Social Media Planning     Charlie  1/28/2024             22
# 3     Marketing      Campaign Analysis       Daisy  2/18/2024             25
# 4   Product Dev  Prototype Development       Ethan   1/2/2024             18
# 5   Product Dev      Quality Assurance       Fiona  1/20/2024             10
# 6   Product Dev  User Interface Design     Gabriel   2/4/2024             25
# 7  Customer Svc    Service Improvement      Hannah   2/1/2024             22
# 8  Customer Svc      Ticket Resolution         Ian  2/24/2024             25
#
#     End Date Progress
# 0  1/14/2024      78%
# 1  1/28/2024     100%
# 2  2/19/2024      45%
# 3  3/14/2024       0%
# 4  1/20/2024     100%
# 5  1/30/2024      78%
# 6  2/29/2024       0%
# 7  2/23/2024     100%
# 8  3/20/2024     100%

# %%
min_r=dataset["Days Required"].min()
max_r= dataset["Days Required"].max()

# %%
min_r,max_r
# Out:
# (10, 60)

# %% [raw]
# range = max_r - min_r

# %%
range
# Out:
# range
