# %%
pip install matplotlab
# Out:
# ...
#
#   Using cached matplotlab-0.1.7-py3-none-any.whl.metadata (8.9 kB)
# ...

# %%
pip install gymnasium
# Out:
# ...
#    ---------------------------------------- 0.0/952.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/952.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/952.1 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/952.1 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/952.1 kB ? eta -:--:--
#    -------------------- ----------------- 524.3/952.1 kB 524.3 kB/s eta 0:00:01
#    -------------------- ----------------- 524.3/952.1 kB 524.3 kB/s eta 0:00:01
#    ------------------------------- ------ 786.4/952.1 kB 633.2 kB/s eta 0:00:01
#    -------------------------------------- 952.1/952.1 kB 690.0 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlab.pyplot
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlab.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlab.pyplot

# %%
pip install torch

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn  as sns

# %%
ar =np.array([1,4,2,76,9,87,45,87,56,23,56,76,87])
len(ar)
# Out:
# 13

# %%
np.sum(ar)
# Out:
# 609

# %%
np.sum(ar)/len(ar)
# Out:
# 46.84615384615385

# %%
np.mean(ar)
# Out:
# 46.84615384615385

# %%
dataset= pd.read_csv("airlines(in).csv")

# %%
dataset.head(5)
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
#
#    Time.Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 0           6            June       2003                            1009
# 1           6            June       2003                             374
# 2           6            June       2003                             296
# 3           6            June       2003                             300
# 4           6            June       2003                             283
#
#    Statistics.# of Delays.Late Aircraft  \
# ...

# %%
dataset["Statistics.Flights.Diverted"].mean()
# Out:
# 27.88089836660617

# %%
mn=np.mean(dataset["Statistics.Flights.Diverted"])
print (mn)
# Out:
# 27.88089836660617

# %%
sns.histplot(x="Statistics.Flights.Diverted" ,data = dataset,bins =[i for i in range (0 ,400,1)])
plt.plot([mn for  i in range (0,400)],[i for i in range (0,400)],c="red")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.show()

# %%
# median :
# sort the elements and pik middle element 
# if even no. of element then find everage of the midle two elements

# %%
np.median(dataset["Statistics.Flights.Diverted"])
# Out:
# 15.0

# %%
dataset["Statistics.Flights.Diverted"].fillna(dataset["Statistics.Flights.Diverted"].mean(),inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19796\3039492815.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Statistics.Flights.Diverted"].fillna(dataset["Statistics.Flights.Diverted"].mean(),inplace=True)

# %%
np.median(dataset["Statistics.Flights.Diverted"])
# Out:
# 15.0

# %%
data2= pd.read_csv("practice1.csv")

# %%
data2.head(50)
# Out:
#     Project Name                Task Name Assigned to Start Date  \
# 0      Marketing          Market Research       Alice   1/1/2024
# 1      Marketing         Content Creation         Bob  1/14/2024
# 2      Marketing    Social Media Planning     Charlie  1/28/2024
# 3      Marketing        Campaign Analysis       Daisy  2/18/2024
# 4    Product Dev    Prototype Development       Ethan   1/2/2024
# 5    Product Dev        Quality Assurance       Fiona  1/20/2024
# 6    Product Dev    User Interface Design     Gabriel   2/4/2024
# 7   Customer Svc      Service Improvement      Hannah   2/1/2024
# 8   Customer Svc        Ticket Resolution         Ian  2/24/2024
# 9   Customer Svc        Customer Feedback       Julia  3/21/2024
# 10     Financial          Budget Analysis       Kevin   2/2/2024
# 11     Financial      Financial Reporting        Mark  2/13/2024
# 12     Financial      Investment Planning        Mark  3/19/2024
# ...

# %%
mn=np.mean(data2["Days Required"])

# %%
md=np.median(data2["Days Required"])

# %%
data2["Days Required"].mean()
# Out:
# 26.47826086956522

# %%
print (mn)
# Out:
# 26.47826086956522

# %%
print (md)
# Out:
# 25.0

# %%
sns.histplot(x= "Days Required",data =data2,bins =[ i for i in range (10,38,1)] )
plt.plot([md for i  in range(0,10)],[i for i in range (0,10)],c="red",label = "median")
plt.plot ([mn for i in range (0,10)],[i for i in range (0,10)],c="green",label ="mean")
plt.plot ([mo for i in range (0,10)],[i for i in range (0,10)] ,c="blue",label = "mode")
plt.show()

# %% [markdown]
# # mod

# %% [raw]
# most frequency data

# %%
mo =data2['Project Name'].mode()[0]

# %%
print (mo)
# Out:
# Marketing

# %%
data2 ['Project Name'].value_counts()
# Out:
# Project Name
# Marketing       4
# Product Dev     3
# Customer Svc    3
# Financial       3
# Research        3
# Development     3
# Production      3
# Sales           3
# Support         3
# Operations      3
# Consulting      3
# Training        3
# Events          3
# Logistics       3
# Engineering     3
# Name: count, dtype: int64
