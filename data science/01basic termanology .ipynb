# %% [raw]
# datascience math
# meachine learning
# leeplearning
# datacleaning
# Ensemble Learning

# %% [raw]
# # population date (N)
#     whole set of values
#
# mean
# standard deviation
# population
# median
#
# # sample data(n)

# %%
staticstics

descriptive 
    method applied on entire data population data
inferantial 
     methodes on the sample data

# %%
descriptive statics 
1 measure of central tendency (mean medial mode )
2 measurement of variability (range ,mean absulate division  ,veriance ,sandard dviation )
3 measurement of shape (skewness )
4 percentile (boxplot )
5 frquency destribrution (plot)
6 covariance and corelation 


# inferential 

1centrl limit theorem 
2 hypoyhesis test 
    z test 
    T test
    chi square test
