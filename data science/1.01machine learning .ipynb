# %% [markdown]
# # meachine learning

# %% [raw]
# 1 superwisw machine learning  (predict )
# 2.unsuperwise machne learning  (divide data)
# 3.reinforcement machine learning  (bot game )change according to your moment

# %% [raw]
# languger :python ,R
# exploeing data analysis
# Feature enginering
# feature selection
# machine learning algorithm
#     regression and identification
#     clusturing
# linear logistic regrasion ,decision tree ,random forest kmeans
# hyperparameter tunning
# gridsearch ,randonisedsreach,hyperopot,genetic algorithm
# dockers and cubernet
# model deployenments
# end to end ml projects

# %% [raw]
# numpy
# matplotlib
# seaborn
# scikit
# scipy
# tencerflow
# analtk
# opencv

# %% [markdown]
# # datatypes

# %% [raw]
# types of data
# variables
#     numrical
#         destric
#         continuous
#     categorical
#         ordinal(inter conniction )
#         nominal(random )
#     dates and times
#     mixed
