# %%
cd "virtual env"
# Out:
# C:\Users\HP\Desktop\virtual env

# %%
#create virtual environment 
pythom -m venv myenv

# %%
# active virtual invironment (linux ,mac )
source myenv/bin/activate

# %%
# for windows 
myenv/Scripts/activate.bat

# for powershell
myenv/Scripts/activate.ts1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 # for windows
# ----> 2 myenv/Scripts/activate.bat
#
# NameError: name 'myenv' is not defined

# %%
venv -v
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 venv -v
#
# NameError: name 'venv' is not defined

# %%
# deactivate foe deactivate the environment 
deactivate

# %%
# 
pip freeze > requirnment.txt

# %%
pip install -r requirment.txt
