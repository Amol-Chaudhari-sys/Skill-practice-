# %%
questions =[["what is my name ","Amol","aishwarya","soham","swapnil"],["what is my name ","Amol","aishwarya","soham","swapnil"],["what is my name ","Amol","aishwarya","soham","swapnil"],["what is my name ","Amol","aishwarya","soham","swapnil"],["what is my name ","Amol","aishwarya","soham","swapnil"],["what is my name ","Amol","aishwarya","soham","swapnil"],["what is my name ","Amol","aishwarya","soham","swapnil"],["what is my name ","Amol","aishwarya","soham","swapnil"],["what is my name ","Amol","aishwarya","soham","swapnil"]]

level =[10000,50000,75000,80000,100000,120000,150000,175000]
question
amt = 0 
for i in range (0, len (questions)):
    question = questions[i]
    print (f"question for Rs :{level[i]}")
    print (question[0])
    print (f"a {question [1]} b. {question [2]}")
    print (f"c {question [3]} c. {question [4]}")
    ans= int (input("enter the option 1-4 :"))
    if ans==1:
        print(" you win") 
        amt = amt+level[i]
    elif ans==2:
        print ("you loss !!! ")
        break 
    elif ans ==3:
        print ("you loss !!!!")
        break
    else:
        print ("you loss !!!")
        break
print (f"you win amount {amt}")
# Out:
# question for Rs :10000
# what is my name
# a Amol b. aishwarya
# c soham c. swapnil
# enter the option 1-4 : 1
#  you win
# question for Rs :50000
# what is my name
# a Amol b. aishwarya
# c soham c. swapnil
# enter the option 1-4 : 1
#  you win
# question for Rs :75000
# what is my name
# a Amol b. aishwarya
# c soham c. swapnil
# enter the option 1-4 : 1
#  you win
# question for Rs :80000
# what is my name
# a Amol b. aishwarya
# c soham c. swapnil
# enter the option 1-4 : 1
#  you win
# question for Rs :100000
# what is my name
# a Amol b. aishwarya
# c soham c. swapnil
# enter the option 1-4 : 1
#  you win
# question for Rs :120000
# what is my name
# a Amol b. aishwarya
# c soham c. swapnil
# enter the option 1-4 : 3
# you loss !!!!
# you win amount 315000
