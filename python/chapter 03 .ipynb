# %%
name = "\'Cha\'uDhari \n am\tol"  # escapr characters \n \t \; \\

print (name [:])
# slicing 
print (name [1:7:2]) # start with 1 end with 7 and jump 2 steps 
print (len (name))
print (name.startswith ("ch"))
print (name.endswith ("ari"))
print (name.upper())
# Out:
# 'Cha'uDhari
#  am	ol
# Cau
# 19
# False
# False
# 'CHA'UDHARI
#  AM	OL

# %%
name = (input ("Enter the name "))
print (f"good afternoon {name}" )
# Out:
# Enter the name  amol
# good afternoon amol

# %%
letter = '''Dear <Name>
your selected !
<Date>'''

print (letter.replace("<Name>","amol").replace("<Date>", "25oct2025"))
# Out:
# Dear amol
# your selected !
# 25oct2025

# %%
#double spaces 
name ="amol  chaudhari"
age = "20"
n=name.find("  ")
print (name[n-1:n+3])
print (name .find ("ch"))
print (name.replace ("  "," "))
# Out:
# l  c
# 6
# amol chaudhari

# %%
name ="amol chauDhari"
age = "20"
age.isalnum()
name.isalnum() # return true if wide space is not present
# Out:
# True

# %%
print(name.strip("i"))
print (name)
# Out:
# amol chauDhar
# amol chauDhari

# %%
print (name.capitalize())
print (len (name))
print (name.center(100))
print (len (name.center(50)))
# Out:
# Amol chaudhari
# 14
#                                            amol chauDhari
# 50

# %%
print (name.endswith ("ha",5,8))
# Out:
# True

# %%
import time 
timestamp = time.strftime("%H,%M,%S")
timestamp
# Out:
# '16,03,22'
