# %%
import random 
yd={"r": -1,"p": 0,"s": 1  }
rd ={-1:"rock", 0:"paper",1: "seasor"}
while True:
    cc=random.choice ([-1,0,1])
    y =input ("Enter your choice ")
    print (f" your choice is {y} \n and computer choice is  {rd [cc]} ")
    
    if (yd[y]==-1 and cc==-1 ):  # 0  -2   0   tie
        print ("tie")
    elif (yd[y]==-1 and cc==1):  # 2  0    -2   win
        print ("you win ")
    elif (yd[y]==-1 and cc==0):  # 1   -1   -1
        print ("you loss ")
    if (yd[y]==1 and cc==-1 ): # 2    0     2
        print ("you loss ")
    elif (yd[y]==1 and cc==1):  #0   2     tie
        print ("tie ")
    elif (yd[y]==1 and cc==0):  #-1    1     1   win
        print ("you win  ")
    if (yd[y]==0 and cc==-1 ):  #-1   -1    1    win 
        print ("you win")
    elif (yd[y]==0 and cc==1):   #1    1    -1
        print ("you loss ")
    elif (yd[y]==0 and cc==0):   #0     0    0  tie
        print ("tie ")
# Out:
# Enter your choice  r
#  your choice is r
#  and computer choice is  rock
# tie

# %%
# short logic 
import random 
yd={"r": -1,"p": 0,"s": 1  }
rd ={-1:"rock", 0:"paper",1: "seasor"}
while True:
    cc=random.choice ([-1,0,1])
    y =input ("Enter your choice ")
    print (f" your choice is {y} \n and computer choice is  {rd [cc]} ")

    dif = yd[y]-cc 
    if (dif ==-2 or dif ==1):
        print ("win" )
    
    else :
        print ("loose")
        break
# Out:
# Enter your choice  r
#  your choice is r
#  and computer choice is  rock
# loose

# %% [markdown]
# # snake water gun

# %%
import random 
option =['s','w','g']
while True :
    you= int (input ("enter your choice 1. gun  2 water 3.snake "))
    if (you !=1 and you != 2 and you != 3 ):
        print ("invalid input ")
        continue  
    comp= random.choice(option)
    print (comp)
    if (comp =='s'):
        if you==3:
            print ("tie ")
        elif(you==1):
            print ("you win" )
        else:
            print ("you loss ")
            break
    elif(comp =='w'):
        if you == 2:
            print ("tie ")
        elif (you==3):
            print ("you win ")
        else:
            print ("you loss ")
            break
    else :
        if you == 1:
            print ("tie ")
        elif (you==2):
            print ("you win ")
        else:
            print ("you loss ")
            break
# Out:
# enter your choice 1. gun  2 water 3.snake  1
# w
# you loss

# %%
import random 
comp=random .randint(0,2)
you =int (input ("Enter your input 0.for snake  1 for water 2 gun"))


def check (comp ,you ):
    if you ==comp :
        return 0
    if (comp==0)and (you==1):
        return -1
    if (comp==1)and (you==2):
        return -1
    if (comp==2)and (you==0):
        return -1
    return 1

choice ={0: "snake ",1:"water",2:"Gun"}

print (f"your choice {choice[you]} ")
print (f"comp  choice {choice[comp]} ")

score =check(comp ,you)

if score==0:
    print ("tie  ")
elif (score-1):
    print ("you loss")
else: 
    print ("you win    ")
# Out:
# Enter your input 0.for snake  1 for water 2 gun 2
# your choice Gun
# comp  choice Gun
# tie
