# %%
def linear_search(cards ,target ):
    position =0 

    while True :
        if cards[position ]==target :
            return position
        position +=1

        if position ==len(cards):
            return -1



cards =[12,11,9,7,6,4,2]
target = 2
r= linear_search(cards ,target )
print (r)
# Out:
# 6
