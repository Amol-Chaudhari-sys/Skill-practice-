# %%
set1 ={1,2,4,3,6,7,8,10,11,12}
set2={10,11,12,13,14,15,16}

# %%
# set 
len ()
add()
clear()
copy ()
discart()
remove()
union ()
intersection()
diffrance()
symmertic_diffrance()

# %%
print (set1|set2)
print (set1.union(set2))
# Out:
# {1, 2, 3, 4, 6, 7, 8, 10, 11, 12, 13, 14, 15, 16}
# {1, 2, 3, 4, 6, 7, 8, 10, 11, 12, 13, 14, 15, 16}

# %%
print (set1&set2)
print( set1.intersection(set2))
# Out:
# {10, 11, 12}
# {10, 11, 12}

# %%
print (set1-set2)
print (set2-set1)
# Out:
# {1, 2, 3, 4, 6, 7, 8}
# {16, 13, 14, 15}

# %%
print(set1^set2)
print (set1.symmetric_difference(set2))  # allelements other then common element
# Out:
# {1, 2, 3, 4, 6, 7, 8, 13, 14, 15, 16}
# {1, 2, 3, 4, 6, 7, 8, 13, 14, 15, 16}

# %%
ls=[1,2,1,3,1,4,2,5,4,6,5,7,0,4,67,7,9]
set1= set(ls)
print(set1)
ls=list(set1)
ls
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 67, 9}
# [0, 1, 2, 3, 4, 5, 6, 7, 67, 9]

# %%
# Dictionary map hashmap

# %%
x=set({})
y= {}
type(x)
# Out:
# set

# %%
dic1={1:"amol",2:"chaudhari", 3:"Amol", 4:"CHAUDHARI"}

# %%
dic1[5]="CHAUDHARI"

# %%
dic1
# Out:
# {1: 'amol', 2: 'chaudhari', 3: 'Amol', 4: 'wara', 5: 'CHAUDHARI'}

# %%
print(dic1.items())
for i , j in dic1.items():
    print (i,j)
# Out:
# dict_items([(1, 'amol'), (2, 'chaudhari'), (3, 'Amol'), (4, 'wara'), (5, 'CHAUDHARI')])
# 1 amol
# 2 chaudhari
# 3 Amol
# 4 wara
# 5 CHAUDHARI

# %%
dic1.keys()
# Out:
# dict_keys([1, 2, 3, 4, 5])

# %%
dic1.values()
# Out:
# dict_values(['amol', 'chaudhari', 'Amol', 'wara', 'CHAUDHARI'])

# %%
ls=['amol','chaudhari', 'amol','chaudhari', 'AMOL']
s="amol', 'chaudhari', 'Amol', 'wara', 'CHAUDHARI"
freq={}
for name in s:
    if name not in freq:
        freq[name]=1
    else :
        freq[name]+=1

freq
# Out:
# {'a': 5,
#  'm': 2,
#  'o': 2,
#  'l': 2,
#  "'": 8,
#  ',': 4,
#  ' ': 4,
#  'c': 1,
#  'h': 2,
#  'u': 1,
#  'd': 1,
#  'r': 2,
#  'i': 1,
#  'A': 3,
#  'w': 1,
#  'C': 1,
#  'H': 2,
#  'U': 1,
#  'D': 1,
#  'R': 1,
#  'I': 1}
