# %%
class Node :
    def __init__(self, data ):
        self.data= data
        self.l= None
        self.r= None

# %%
# pre order 
ans=[]
def preorder(root ):
    if root is None :
        return
    ans.append (root.data)
    preorder(root.left)
    preorder(root.right)

# %%
# post order
def postorder(root):
    if root is None :
        return 
    postorder(root.rigth)
    postorder(root.left)
    ans.append(root.data)
